# %%
import numpy as np

# %%
Monkey_0 = [74, 64, 74, 63, 53]
Monkey_1 = [69, 99, 95, 62]
Monkey_2 = [59, 81]
Monkey_3 = [50, 67, 63, 57, 63, 83, 97]
Monkey_4 = [61, 94, 85, 52, 81, 90, 94, 70]
Monkey_5 = [69]
Monkey_6 = [54, 55, 58]
Monkey_7 = [79, 51, 83, 88, 93, 76]
counter_0 = 0
counter_1 = 0
counter_2 = 0
counter_3 = 0
counter_4 = 0
counter_5 = 0
counter_6 = 0
counter_7 = 0

def Throw(Monkey_Number):
    global Monkey_0
    global Monkey_1
    global Monkey_2
    global Monkey_3
    global Monkey_4
    global Monkey_5
    global Monkey_6
    global Monkey_7
    global counter_0
    global counter_1
    global counter_2
    global counter_3
    global counter_4
    global counter_5
    global counter_6
    global counter_7
    
    
    if Monkey_Number == 0:
        for i in Monkey_0:
            counter_0 = counter_0 + 1
            value = i * 7
            value = np.floor(value / 3)
            if value % 5 == 0:
                Monkey_1.append(value)
            else:
                Monkey_6.append(value)
        Monkey_0 = []
    
    if Monkey_Number == 1:
        for i in Monkey_1:
            counter_1 = counter_1 + 1
            value = i * i
            value = np.floor(value / 3)
            if value % 17 == 0:
                Monkey_2.append(value)
            else:
                Monkey_5.append(value)
        Monkey_1 = []
        
    if Monkey_Number == 2:
        for i in Monkey_2:
            counter_2 = counter_2 + 1
            value = i + 8
            value = np.floor(value / 3)
            if value % 7 == 0:
                Monkey_4.append(value)
            else:
                Monkey_3.append(value)
        Monkey_2 = []
        
    if Monkey_Number == 3:
        for i in Monkey_3:
            counter_3 = counter_3 + 1
            value = i + 4
            value = np.floor(value / 3)
            if value % 13 == 0:
                Monkey_0.append(value)
            else:
                Monkey_7.append(value)
        Monkey_3 = []
        
    if Monkey_Number == 4:
        for i in Monkey_4:
            counter_4 = counter_4 + 1
            value = i + 3
            value = np.floor(value / 3)
            if value % 19 == 0:
                Monkey_7.append(value)
            else:
                Monkey_3.append(value)
        Monkey_4 = []
        
    if Monkey_Number == 5:
        for i in Monkey_5:
            counter_5 = counter_5 + 1
            value = i + 5
            value = np.floor(value / 3)
            if value % 3 == 0:
                Monkey_4.append(value)
            else:
                Monkey_2.append(value)
        Monkey_5 = []
        
    if Monkey_Number == 6:
        for i in Monkey_6:
            counter_6 = counter_6 + 1
            value = i + 7
            value = np.floor(value / 3)
            if value % 11 == 0:
                Monkey_1.append(value)
            else:
                Monkey_5.append(value)
        Monkey_6 = []
        
    if Monkey_Number == 7:
        for i in Monkey_7:
            counter_7 = counter_7 + 1
            value = i * 3
            value = np.floor(value / 3)
            if value % 2 == 0:
                Monkey_0.append(value)
            else:
                Monkey_6.append(value)
        Monkey_7 = []      
    return

for j in np.arange(20):
    Throw(0)
    Throw(1)
    Throw(2)
    Throw(3)
    Throw(4)
    Throw(5)
    Throw(6)
    Throw(7)

counter = [counter_0, counter_1, counter_2, counter_3, counter_4, counter_5, counter_6, counter_7]
counter_Max = 0
counter_Second = 0
for q in counter:
    if q >= counter_Max:
        counter_Second = counter_Max
        counter_Max = q
    else:
        if q >= counter_Second:
            counter_Second = q
print(counter_Max * counter_Second)
# Out:
# 54054

# %%
Monkey_0 = [74, 64, 74, 63, 53]
Monkey_1 = [69, 99, 95, 62]
Monkey_2 = [59, 81]
Monkey_3 = [50, 67, 63, 57, 63, 83, 97]
Monkey_4 = [61, 94, 85, 52, 81, 90, 94, 70]
Monkey_5 = [69]
Monkey_6 = [54, 55, 58]
Monkey_7 = [79, 51, 83, 88, 93, 76]
counter_0 = 0
counter_1 = 0
counter_2 = 0
counter_3 = 0
counter_4 = 0
counter_5 = 0
counter_6 = 0
counter_7 = 0

def Throw(Monkey_Number):
    global Monkey_0
    global Monkey_1
    global Monkey_2
    global Monkey_3
    global Monkey_4
    global Monkey_5
    global Monkey_6
    global Monkey_7
    global counter_0
    global counter_1
    global counter_2
    global counter_3
    global counter_4
    global counter_5
    global counter_6
    global counter_7
    
    
    if Monkey_Number == 0:
        for i in Monkey_0:
            counter_0 = counter_0 + 1
            value = i * 7
            value = value % 9699690
            if value % 5 == 0:
                Monkey_1.append(value)
            else:
                Monkey_6.append(value)
        Monkey_0 = []
    
    if Monkey_Number == 1:
        for i in Monkey_1:
            counter_1 = counter_1 + 1
            value = i * i
            value = value % 9699690
            if value % 17 == 0:
                Monkey_2.append(value)
            else:
                Monkey_5.append(value)
        Monkey_1 = []
        
    if Monkey_Number == 2:
        for i in Monkey_2:
            counter_2 = counter_2 + 1
            value = i + 8
            value = value % 9699690
            if value % 7 == 0:
                Monkey_4.append(value)
            else:
                Monkey_3.append(value)
        Monkey_2 = []
        
    if Monkey_Number == 3:
        for i in Monkey_3:
            counter_3 = counter_3 + 1
            value = i + 4
            value = value % 9699690
            if value % 13 == 0:
                Monkey_0.append(value)
            else:
                Monkey_7.append(value)
        Monkey_3 = []
        
    if Monkey_Number == 4:
        for i in Monkey_4:
            counter_4 = counter_4 + 1
            value = i + 3
            value = value % 9699690
            if value % 19 == 0:
                Monkey_7.append(value)
            else:
                Monkey_3.append(value)
        Monkey_4 = []
        
    if Monkey_Number == 5:
        for i in Monkey_5:
            counter_5 = counter_5 + 1
            value = i + 5
            value = value % 9699690
            if value % 3 == 0:
                Monkey_4.append(value)
            else:
                Monkey_2.append(value)
        Monkey_5 = []
        
    if Monkey_Number == 6:
        for i in Monkey_6:
            counter_6 = counter_6 + 1
            value = i + 7
            value = value % 9699690
            if value % 11 == 0:
                Monkey_1.append(value)
            else:
                Monkey_5.append(value)
        Monkey_6 = []
        
    if Monkey_Number == 7:
        for i in Monkey_7:
            counter_7 = counter_7 + 1
            value = i * 3
            value = value % 9699690
            if value % 2 == 0:
                Monkey_0.append(value)
            else:
                Monkey_6.append(value)
        Monkey_7 = []      
    return

for j in np.arange(10000):
    Throw(0)
    Throw(1)
    Throw(2)
    Throw(3)
    Throw(4)
    Throw(5)
    Throw(6)
    Throw(7)

counter = [counter_0, counter_1, counter_2, counter_3, counter_4, counter_5, counter_6, counter_7]
counter_Max = 0
counter_Second = 0
for q in counter:
    if q >= counter_Max:
        counter_Second = counter_Max
        counter_Max = q
    else:
        if q >= counter_Second:
            counter_Second = q
print(counter_Max * counter_Second)
# Out:
# 14314925001
